# %%
personaje = "Mortaccio"
minutos_sobrevivido = 18
enemigos_eliminados = 4823
victoria = True

print(personaje)
print(minutos_sobrevivido)
# Out:
# Mortaccio
# 18

# %%
print(enemigos_eliminados)
print(victoria)
print(type(personaje))
print(type(minutos_sobrevivido))
# Out:
# 4823
# True
# <class 'str'>
# <class 'int'>
