# %%
partida = ["Mortaccio", 18, 4823, True]

print(partida)
print(type(partida))
# Out:
# ['Mortaccio', 18, 4823, True]
# <class 'list'>

# %%
# Tu lista:
# ["Mortaccio", 18, 4823, True]
#       0        1    2     3

print(partida[0])  # Mortaccio
print(partida[1])  # 18
print(partida[2])  # 4823
print(partida[3])  # True
# Out:
# Mortaccio
# 18
# 4823
# True

# %%
print(partida[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(partida[4])
#
# IndexError: list index out of range

# %%
partidas = [
    ["Mortaccio", 18, 4823, True],
    ["Imelda", 12, 2100, False],
    ["Clerici", 25, 7654, True]
]

print(partidas[0])        # toda la primera partida
print(partidas[1][0])     # personaje de la segunda partida
print(partidas[2][1])     # minutos de la tercera partida
# Out:
# ['Mortaccio', 18, 4823, True]
# Imelda
# 25
