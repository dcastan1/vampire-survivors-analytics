# %%
import pandas as pd

# %%
partidas = [
    {"jugador": "Carlos", "personaje": "Mortaccio", "minutos": 18, "enemigos": 4823, "victoria": True},
    {"jugador": "María", "personaje": "Imelda", "minutos": 12, "enemigos": 2100, "victoria": False},
    {"jugador": "Luis", "personaje": "Clerici", "minutos": 25, "enemigos": 7654, "victoria": True},
    {"jugador": "Ana", "personaje": "Mortaccio", "minutos": 8, "enemigos": 1200, "victoria": False},
    {"jugador": "Carlos", "personaje": "Clerici", "minutos": 30, "enemigos": 9100, "victoria": True}
]

df = pd.DataFrame(partidas)
print(df)
# Out:
#   jugador  personaje  minutos  enemigos  victoria
# 0  Carlos  Mortaccio       18      4823      True
# 1   María     Imelda       12      2100     False
# 2    Luis    Clerici       25      7654      True
# 3     Ana  Mortaccio        8      1200     False
# 4  Carlos    Clerici       30      9100      True

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# (5, 5)
# Index(['jugador', 'personaje', 'minutos', 'enemigos', 'victoria'], dtype='object')
# jugador      object
# personaje    object
# minutos       int64
# enemigos      int64
# victoria       bool
# dtype: object

# %%
print(df["victoria"].value_counts())
print(df["enemigos"].max())
print(df["minutos"].mean())
# Out:
# victoria
# True     3
# False    2
# Name: count, dtype: int64
# 9100
# 18.6

# %%
# Solo las victorias
victorias = df[df["victoria"] == True]
print(victorias)

# Solo partidas de más de 15 minutos
partidas_largas = df[df["minutos"] > 15]
print(partidas_largas)
# Out:
#   jugador  personaje  minutos  enemigos  victoria
# 0  Carlos  Mortaccio       18      4823      True
# 2    Luis    Clerici       25      7654      True
# 4  Carlos    Clerici       30      9100      True
#   jugador  personaje  minutos  enemigos  victoria
# 0  Carlos  Mortaccio       18      4823      True
# 2    Luis    Clerici       25      7654      True
# 4  Carlos    Clerici       30      9100      True

# %%
#Solo partidas de Carlos
PCarlos=df[df["jugador"]=="Carlos"]
print(PCarlos)
# Out:
#   jugador  personaje  minutos  enemigos  victoria
# 0  Carlos  Mortaccio       18      4823      True
# 4  Carlos    Clerici       30      9100      True

# %%
print(PCarlos["enemigos"].mean())
# Out:
# 6961.5
